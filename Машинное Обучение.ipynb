# %% [markdown]
# ### Машинное Обучение [Домашнее задание]

# %% [markdown]
# 1. У вас есть файл ```"spam.csv"``` со spam & non-spam (ham) сообщениями, загрузите его в pandas.DataFrame ```data```.

# %%
#Начало вашего кода
import pandas as pd

data = pd.read_csv("spam.csv", encoding='latin-1')
data = data.drop(columns = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])
#Конец вашего кода
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Извлеките данные из dataframe в ```numpy.ndarrays``` ```X``` и ```y```.

# %%
#Начало вашего кода
import numpy as np
X = []
y = []

for row1, row2 in zip(data["v1"],data["v2"]):
    y.append(row1)
    X.append(row2)                  
X = np.array(X)
y = np.array(y)

#Конец вашего кода
print(X[:5])
print(y[:5])
# Out:
# ['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'
#  'Ok lar... Joking wif u oni...'
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"
#  'U dun say so early hor... U c already then say...'
#  "Nah I don't think he goes to usf, he lives around here though"]
# ['ham' 'ham' 'spam' 'ham' 'ham']

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# ['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'
#  'Ok lar... Joking wif u oni...'
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"
#  'U dun say so early hor... U c already then say...'
#  "Nah I don't think he goes to usf, he lives around here though"]
# ['ham' 'ham' 'spam' 'ham' 'ham']
# ```

# %% [markdown]
# 3. Теперь вы должны реализовать модуль ```dataset.py```, который содержит класс ```class Dataset()```. Класс Dataset () должен иметь следующую структуру:
#
# ```
# import numpy as np
#
# class Dataset:
#     def __init__(self, X, y):
#         self._x = X
#         self._y = y
#         self.num2label = {}
#         self.label2num = {}
#         self._transform()
#
#     def __len__(self):
#         '''
#         Этот метод возвращает размер набора данных.
#         '''
#         # Начало вашего кода
#
#         # Конец вашего кода
#
#     def _transform(self):
#         '''
#         Этот метод очищает набор данных X, а также конвертирует y в числа.
#         '''
#         # Начало вашего кода
#
#         # Конец вашего кода
#         pass
#
#     def split_dataset(self, val=0.1, test=0.1):
#         datasets = {}
#         '''
#         Этот метод разделяет набор данных на train, validation, test,
#         и присваивает словарю "datasets" со следующие ключи: "train", "validation" и "test"
#         Установите np.random.seed(1).
#         '''
#         # Начало вашего кода
#
#         # Конец вашего кода
#         return datasets
# ```

# %%
from dataset import Dataset
dataset = Dataset(X,y)
print(len(dataset))
# Out:
# 5572

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# 5572
# ```

# %% [markdown]
# 4. Вызовите метод ```split_dataset()``` и проверьте результаты.

# %%
# Начало вашего кода
datasets = dataset.split_dataset()
# Конец вашего кода

for key in datasets:
    print(f"{key} datasets: length of x: {len(datasets[key][0])} and y: {len(datasets[key][1])}")
# Out:
# train datasets: length of x: 4458 and y: 4458
# validation datasets: length of x: 557 and y: 557
# test datasets: length of x: 557 and y: 557

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# train datasets: length of x: 4458 and y: 4458
# val datasets: length of x: 557 and y: 557
# test datasets: length of x: 557 and y: 557
# ```

# %%
for i in range(20):
    print(f"{datasets['train'][0][i]}", end=" ---> ")
    print(dataset.num2label[datasets['train'][1][i]])
# Out:
# yeah do don û t stand to close tho you û ll catch something  ---> ham
# sleeping nt feeling well ---> ham
# come aftr lt decimal gt now i m cleaning the house ---> ham
# almost there see u in a sec ---> ham
# yeah probably earlier than that ---> ham
# hello my love what are you doing did you get to that interview today are you you happy are you being a good boy do you think of me are you missing me  ---> ham
# 2mro i am not coming to gym machan goodnight  ---> ham
# free ring tone just text polys to 87131 then every week get a new tone 0870737910216yrs only å 1 50 wk  ---> spam
# camera you are awarded a sipix digital camera call 09061221066 fromm landline delivery within 28 days  ---> spam
# tbs persolvo been chasing us since sept forå 38 definitely not paying now thanks to your information we will ignore them kath manchester  ---> spam
# small problem in auction punj now asking tiwary ---> ham
# ...

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# yeah do don û t stand to close tho you û ll catch something ---> ham
# sleeping nt feeling well ---> ham
# come aftr lt decimal gt now i m cleaning the house ---> ham
# almost there see u in a sec ---> ham
# yeah probably earlier than that ---> ham
# hello my love what are you doing did you get to that interview today are you you happy are you being a good boy do you think of me are you missing me ---> ham
# 2mro i am not coming to gym machan goodnight ---> ham
# free ring tone just text polys to 87131 then every week get a new tone 0870737910216yrs only å 1 50 wk ---> spam
# camera you are awarded a sipix digital camera call 09061221066 fromm landline delivery within 28 days ---> spam
# tbs persolvo been chasing us since sept forå 38 definitely not paying now thanks to your information we will ignore them kath manchester ---> spam
# small problem in auction punj now asking tiwary ---> ham
# we know someone who you know that fancies you call 09058097218 to find out who pobox 6 ls15hb 150p ---> spam
# still chance there if you search hard you will get it let have a try ---> ham
# happened here while you were adventuring ---> ham
# eat at old airport road but now 630 oredi got a lot of pple ---> ham
# sent me ur email id soon ---> ham
# hey you still want to go for yogasana coz if we end at cine then can go bathe and hav the steam bath ---> ham
# two fundamentals of cool life walk ---> ham
# my parents my kidz my friends n my colleagues all screaming surprise and i was waiting on the sofa naked ---> ham
# sorry i missed your call let s talk when you have the time i m on 07090201529 ---> spam
# ```

# %% [markdown]
# ### Отличная работа
